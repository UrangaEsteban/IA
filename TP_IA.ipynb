# %% [markdown]
# <a href="https://colab.research.google.com/github/MarilynDaiana/IA/blob/main/TP_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# link de datasets: https://www.kaggle.com/datasets/sazidthe1/global-electricity-production
#
# https://www.kaggle.com/datasets/willianoliveiragibin/annual-cause-death-numbers/data
#
# https://www.datos.gob.ar/dataset/renaper-nacimientos-argentina/archivo/renaper_6.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importar Pandas

import pandas as pd
ruta_archivo = '/content/drive/MyDrive/IA/Dataset/global_electricity_production_data.csv'

# %%
data = pd.read_csv(ruta_archivo)

data
# Out:
#          country_name       date                       parameter  \
# 0           Australia  12/1/2023      Net Electricity Production
# 1           Australia  12/1/2023      Net Electricity Production
# 2           Australia  12/1/2023      Net Electricity Production
# 3           Australia  12/1/2023      Net Electricity Production
# 4           Australia  12/1/2023      Net Electricity Production
# ...               ...        ...                             ...
# 121069  United States   1/1/2010                   Total Imports
# 121070  United States   1/1/2010                   Total Exports
# 121071  United States   1/1/2010         Used for pumped storage
# 121072  United States   1/1/2010             Distribution Losses
# 121073  United States   1/1/2010  Final Consumption (Calculated)
#
#                                   product        value unit
# 0                             Electricity   22646.1901  GWh
# 1                 Total Combustible Fuels   13397.9356  GWh
# ...

# %%
# Funcion analisis descriptivo basico base de datos:
def descriptivo(datos):
    print("Head")
    display(datos.head())
    print("-----------------------------------------------------------------")
    print("")

    print("Nombre columnas")
    display(datos.columns)
    print("-----------------------------------------------------------------")
    print("")

    print("Shape")
    display(datos.shape)
    print("-----------------------------------------------------------------")
    print("")

    print("Information")
    display(datos.info())
    print("-----------------------------------------------------------------")
    print("")

    print("Describe")
    display(datos.describe())
    print("-----------------------------------------------------------------")
    print("")

    print("Datos ausentes")
    display(datos.isna().sum())
    print("-----------------------------------------------------------------")
    print("")

# %%
descriptivo(data)
# Out:
# Head
#   country_name       date                   parameter  \
# 0    Australia  12/1/2023  Net Electricity Production
# 1    Australia  12/1/2023  Net Electricity Production
# 2    Australia  12/1/2023  Net Electricity Production
# 3    Australia  12/1/2023  Net Electricity Production
# 4    Australia  12/1/2023  Net Electricity Production
#
#                              product       value unit
# 0                        Electricity  22646.1901  GWh
# 1            Total Combustible Fuels  13397.9356  GWh
# 2  Coal, Peat and Manufactured Gases   9768.5223  GWh
# 3         Oil and Petroleum Products    289.5415  GWh
# 4                        Natural Gas   3091.9272  GWh
# -----------------------------------------------------------------
#
# Nombre columnas
# Index(['country_name', 'date', 'parameter', 'product', 'value', 'unit'], dtype='object')
# -----------------------------------------------------------------
#
# Shape
# (121074, 6)
# ...

# %% [markdown]
# VARIBLES NUMERICAS DISCRETA: Year, Meningitis fatalities, Dementia, Parkinson s fatalities, Parkinson s fatalities, Malaria fatalities, Drowning fatalities, Interpersonal violence, Maternal disorder fatalities, Chronic kidney fatalities, Poisoning fatalities, Protein energy malnutrition fatalities, Road injury fatalities, Chronic respiratory fatalities, Chronic liver fatalities, Digestive disease fatalities, Fire fatalities, Acute hepatitis fatalities, Measles fatalities

# %% [markdown]
# VARIABLES CATEGORICAS ORDINAL: Entity

# %% [markdown]
# **Gráficos**

# %%
# !pip install seaborn

# %%
#ignore warnings

import warnings

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
# Import the dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Importar Seaborn

# %%
# Import seaborn

import seaborn as sns

# %%
data_country = data.groupby('country_name')['value'].sum()

# %%
plt.figure(figsize=(10,6))

# %%
data_country.plot(kind='bar')
plt.title('Total de producción por país')
plt.xlabel('País')
plt.show()

# %% [markdown]
# El país que tiene mayor producción eléctrica es Estados Unidos

# %%
data_product = data.groupby('product')['value'].sum()

# %%
plt.figure(figsize=(20,6))

# %%
data_product.plot(kind='line')
plt.title('Total de producción por producto')
plt.xlabel('Producto')
plt.show()
